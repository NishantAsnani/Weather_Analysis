# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
dataset=pd.read_csv('weatherAUS.csv')
dataset
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
dataset.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
dataset["WindGustDir"]
# Out:
# 0           W
# 1         WNW
# 2         WSW
# 3          NE
# 4           W
#          ...
# 145455      E
# 145456    NNW
# 145457      N
# 145458     SE
# 145459    NaN
# Name: WindGustDir, Length: 145460, dtype: object

# %%
Mean_Sunshine=dataset["Sunshine"].mean()
print(Mean_Sunshine)

dataset["Sunshine"].fillna(Mean_Sunshine,inplace=True)
# Out:
# 7.6111775206611565

# %%
dataset["WindGustDir"].fillna(dataset["WindGustDir"].mode()[0],inplace=True)
dataset["WindGustSpeed"].fillna(dataset["WindGustSpeed"].mean(),inplace=True)

# %%
dataset.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine             0
# WindGustDir          0
# WindGustSpeed        0
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
dataset["WindDir9am"].fillna(dataset["WindDir9am"].mode()[0],inplace=True)
dataset["WindDir3pm"].fillna(dataset["WindDir3pm"].mode()[0],inplace=True)

# %%
dataset["WindGustSpeed"].fillna(dataset["WindGustSpeed"].mean(),inplace=True)
dataset["Evaporation"].fillna(dataset["Evaporation"].mean(),inplace=True)
dataset["Sunshine"].fillna(dataset["Sunshine"].mean(),inplace=True)
dataset["Sunshine"].fillna(dataset["Sunshine"].mean(),inplace=True)

# %%
dataset["WindSpeed9am"].fillna(dataset["WindSpeed9am"].mean(),inplace=True)
dataset["WindSpeed3pm"].fillna(dataset["WindSpeed9am"].mean(),inplace=True)
dataset["Pressure9am"].fillna(dataset["Pressure9am"].mean(),inplace=True)
dataset["Pressure3pm"].fillna(dataset["Pressure3pm"].mean(),inplace=True)

dataset["Humidity9am"].fillna(dataset["Humidity9am"].mean(),inplace=True)
dataset["Humidity3pm"].fillna(dataset["Humidity3pm"].mean(),inplace=True)


dataset["Cloud9am"].fillna(dataset["Cloud9am"].mean(),inplace=True)
dataset["Cloud3pm"].fillna(dataset["Cloud3pm"].mean(),inplace=True)

dataset["Temp9am"].fillna(dataset["Temp9am"].mean(),inplace=True)
dataset["Temp3pm"].fillna(dataset["Temp3pm"].mean(),inplace=True)

dataset["MinTemp"].fillna(dataset["MinTemp"].mean(),inplace=True)
dataset["MaxTemp"].fillna(dataset["MaxTemp"].mean(),inplace=True)

# %%
dataset.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall    Evaporation  \
# count  145460.000000  145460.000000  142199.000000  145460.000000
# mean       12.194034      23.221348       2.360918       5.468232
# std         6.365750       7.088124       8.478060       3.161541
# min        -8.500000      -4.800000       0.000000       0.000000
# 25%         7.700000      18.000000       0.000000       4.000000
# 50%        12.100000      22.700000       0.000000       5.468232
# 75%        16.800000      28.200000       0.800000       5.468232
# max        33.900000      48.100000     371.000000     145.000000
#
#             Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  145460.000000  145460.000000  145460.000000  145460.000000
# mean        7.611178      40.035230      14.043426      18.565420
# std         2.729486      13.118253       8.861059       8.741767
# min         0.000000       6.000000       0.000000       0.000000
# ...

# %%
dataset["Rainfall"].fillna(dataset["Rainfall"].mean(),inplace=True)

# %%
dataset.isnull().sum()
# Out:
# Date                0
# Location            0
# MinTemp             0
# MaxTemp             0
# Rainfall            0
# Evaporation         0
# Sunshine            0
# WindGustDir         0
# WindGustSpeed       0
# WindDir9am          0
# WindDir3pm          0
# WindSpeed9am        0
# WindSpeed3pm        0
# Humidity9am         0
# Humidity3pm         0
# Pressure9am         0
# Pressure3pm         0
# Cloud9am            0
# Cloud3pm            0
# Temp9am             0
# Temp3pm             0
# RainToday        3261
# RainTomorrow     3267
# dtype: int64

# %%
df=pd.DataFrame(dataset)
df.isnull().sum()
# Out:
# Date                0
# Location            0
# MinTemp             0
# MaxTemp             0
# Rainfall            0
# Evaporation         0
# Sunshine            0
# WindGustDir         0
# WindGustSpeed       0
# WindDir9am          0
# WindDir3pm          0
# WindSpeed9am        0
# WindSpeed3pm        0
# Humidity9am         0
# Humidity3pm         0
# Pressure9am         0
# Pressure3pm         0
# Cloud9am            0
# Cloud3pm            0
# Temp9am             0
# Temp3pm             0
# RainToday        3261
# RainTomorrow     3267
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

fields=["RainToday","RainTomorrow","WindDir9am","WindDir3pm","WindGustDir"] 

le=LabelEncoder()
for cols in fields:
    df[cols]=le.fit_transform(df[cols])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# c:\Users\Dell\Desktop\Internship BISAG-N\CD-Data\Weather_analysis.ipynb Cell 15 line <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/Internship%20BISAG-N/CD-Data/Weather_analysis.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> from sklearn.preprocessing import LabelEncoder
#       <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/Internship%20BISAG-N/CD-Data/Weather_analysis.ipynb#X20sZmlsZQ%3D%3D?line=2'>3</a> fields=["RainToday","RainTomorrow","WindDir9am","WindDir3pm","WindGustDir"]
#       <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/Internship%20BISAG-N/CD-Data/Weather_analysis.ipynb#X20sZmlsZQ%3D%3D?line=4'>5</a> le=LabelEncoder()
#
# File c:\Users\Dell\anaconda3\lib\site-packages\sklearn\__init__.py:82, in <module>
#      80 from . import _distributor_init  # noqa: F401
# ...

# %%
df=df.drop(["Sunshine","Evaporation","Date","Location"],axis=1)


X=df.drop(["RainTomorrow"],axis=1)
y=df[["RainTomorrow"]]  

Y=y["RainTomorrow"]

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.20,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression

reg =LogisticRegression(max_iter=100)
reg.fit(X_train,Y_train)

# %%
print("Accuracy of model is ", reg.score(X_test,Y_test)*100)
y_pred=reg.predict(X_test)

# %%
y_pred

# %%
from sklearn.ensemble import RandomForestClassifier 
RFC=RandomForestClassifier()
RFC.fit(X_train,Y_train)

# %%
print("Accuracy of model is ", RFC.score(X_test,Y_test)*100)
y_pred_1=RFC.predict(X_test)

# %%
from sklearn.tree import DecisionTreeClassifier 
dt=DecisionTreeClassifier()
dt.fit(X_train,Y_train)

# %%
print("Accuracy of model is ",dt.score(X_test,Y_test)*100)
y_pred_2=dt.predict(X_test)

# %%
y_pred_2

# %%
df

# %%
from sklearn.neighbors import KNeighborsClassifier 
neigh = KNeighborsClassifier(n_neighbors=3)
neigh.fit(X_train,Y_train)

# %%
y_pred_3=neigh.predict(X_test)
y_pred_3

# %%
print("Accuracy of model is ",neigh.score(X_test,Y_test)*100)

# %%
from sklearn.linear_model import LinearRegression
lreg=LinearRegression().fit(X, Y)
reg.score(X,Y)

# %%
df

# %%
sns.scatterplot(y=df["Rainfall"],x=df["Humidity9am"])

# %%
sns.scatterplot(y=df["Rainfall"],x=df["Temp3pm"])









Humidity3pm=sns.scatterplot(y=df["Rainfall"],x=df["Humidity3pm"],ax=axes[0,0])
Humidity3pm.set_xlabel("Humidity3pm (in%)")

Humidity9am=sns.scatterplot(y=df["Rainfall"],x=df["Humidity9am"],ax=axes[0,1])
Humidity9am.set_xlabel("Humidity9am (in%)")


Pressure3pm=sns.scatterplot(y=df["Rainfall"],x=df["Pressure3pm"],ax=axes[0,2])
Pressure3pm.set_xlabel("Pressure3pm (in hpa)")

Pressure9am=sns.scatterplot(y=df["Rainfall"],x=df["Pressure9am"],ax=axes[0,3])
Pressure9am.set_xlabel("Pressure9am (in hpa)")

WindGutsSpeed=sns.scatterplot(y=df["Rainfall"],x=df["WindGustSpeed"],ax=axes[1,0])
WindGutsSpeed.set_xlabel("WindGutsSpeed (in km/h)")

MinTemp=sns.scatterplot(y=df["Rainfall"],x=df["MinTemp"],ax=axes[1,1])
MinTemp.set_xlabel("MinTemp (in Celcius)")

MaxTemp=sns.scatterplot(y=df["Rainfall"],x=df["MaxTemp"],ax=axes[1,2])
MaxTemp.set_xlabel("MaxTemp (in Celcius)")

Temp9am=sns.scatterplot(y=df["Rainfall"],x=df["Temp9am"],ax=axes[1,3])
Temp9am.set_xlabel("Temp9am (in Celcius)")

Temp3pm=sns.scatterplot(y=df["Rainfall"],x=df["Temp3pm"],ax=axes[2,0])
Temp3pm.set_xlabel("Temp3pm (in Celcius)")


Cloud9am=sns.scatterplot(y=df["Rainfall"],x=df["Cloud9am"],ax=axes[2,1])
Cloud9am.set_xlabel("Cloud9am (in oktas)")

Cloud3pm=sns.scatterplot(y=df["Rainfall"],x=df["Cloud3pm"],ax=axes[2,2])
Cloud3pm.set_xlabel("Cloud3pm (in oktas)")
